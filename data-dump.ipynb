# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# File paths
datasetss = {
    "Athletes": "data/Athletes.csv",
    "Coaches": "data/Coaches.csv",
    "EntriesGender": "data/EntriesGender.csv",
    "Medals": "data/Medals.csv",
    "Teams": "data/Teams.csv"
}

# %%
for name, path in datasetss.items():
    print(f"\n📊 --- EDA for {name} ---")
    
    try:
        df = pd.read_csv(path, encoding='utf-8')
    except UnicodeDecodeError:
        df = pd.read_csv(path, encoding='latin1')
    
    display(df.head())

    # Basic Info
    print("🧾 Shape:", df.shape)
    print("📌 Columns:", df.columns.tolist())
    print("❓ Null values:\n", df.isnull().sum())
    print("🧹 Duplicate rows:", df.duplicated().sum())
# Out:
# 📊 --- EDA for Athletes ---
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball
# 🧾 Shape: (11085, 3)
# 📌 Columns: ['Name', 'NOC', 'Discipline']
# ❓ Null values:
#  Name          0
# NOC           0
# Discipline    0
# dtype: int64
# 🧹 Duplicate rows: 1
#
# 📊 --- EDA for Coaches ---
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN
# 🧾 Shape: (394, 4)
# 📌 Columns: ['Name', 'NOC', 'Discipline', 'Event']
# ❓ Null values:
#  Name            0
# NOC             0
# ...

# %%
import pandas as pd

for name, path in datasetss.items():
    print(f"\n📊 --- EDA for {name} ---")
    
    try:
        # Read the dataset
        df = pd.read_csv(path, encoding='utf-8')
    except UnicodeDecodeError:
        df = pd.read_csv(path, encoding='latin1')

    # Drop all rows with any missing values
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)

    # Display the cleaned head
    print(f"✅ After dropping nulls, shape = {df.shape}")
    display(df.head())
# Out:
# 📊 --- EDA for Athletes ---
# ✅ After dropping nulls, shape = (11084, 3)
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball
# 📊 --- EDA for Coaches ---
# ✅ After dropping nulls, shape = (248, 4)
#                         Name                       NOC         Discipline  \
# 5  AIKMAN Siegfried Gottlieb                     Japan             Hockey
# 6              AL SAADI Kais                   Germany             Hockey
# 7              ALAMEDA Lonni                    Canada  Baseball/Softball
# 8            ALEKNO Vladimir  Islamic Republic of Iran         Volleyball
# 9            ALEKSEEV Alexey                       ROC           Handball
#
#       Event
# 5       Men
# 6       Men
# 7  Softball
# 8       Men
# ...

# %%
engine = create_engine('postgresql://olympic_user:olympic_pass@localhost:5432/olympics')

# %%
datasets = {
    "Athletes": "data/Athletes.csv",
    "Coaches": "data/Coaches.csv",
    "EntriesGender": "data/EntriesGender.csv",
    "Medals": "data/Medals.csv",
    "Teams": "data/Teams.csv"
}

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# Folder containing cleaned Olympic CSVs
csv_folder = './data'

# List of CSV files
csv_files = [
    "Athletes.csv",
    "Coaches.csv",
    "EntriesGender.csv",
    "Medals.csv",
    "Teams.csv"
]

# PostgreSQL database credentials
db_user = 'olympic_user'
db_password = 'olympic_pass'
db_host = 'localhost'
db_port = '5432'
db_name = 'olympics'

# Connect to PostgreSQL
connection = psycopg2.connect(
    database=db_name,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)

# Create SQLAlchemy engine
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

def load_csv_to_postgresql(csv_file, table_name, conn, engine):
    try:
        df = pd.read_csv(csv_file, encoding='utf-8')
    except UnicodeDecodeError:
        df = pd.read_csv(csv_file, encoding='latin1')

    try:
        # Dynamically create table with all columns as TEXT
        columns = ', '.join([f'"{col}" TEXT' for col in df.columns])
        create_table_query = f"""
            CREATE TABLE IF NOT EXISTS "{table_name}" (
                {columns}
            );
        """

        print(f"\n📥 Creating table '{table_name}'...")
        with conn.cursor() as cursor:
            cursor.execute(create_table_query)
            conn.commit()

        print(f"📊 Inserting data into '{table_name}' ({df.shape[0]} rows)...")
        df.to_sql(table_name, engine, if_exists='replace', index=False, method='multi', chunksize=1000)
        print(f"✅ Loaded {csv_file} into table '{table_name}'.")

    except Exception as e:
        print(f"❌ Error loading {csv_file}: {e}")

# Start uploading all CSVs
if not os.path.exists(csv_folder):
    print(f"❌ Folder '{csv_folder}' not found.")
else:
    for csv_file in csv_files:
        csv_file_path = os.path.join(csv_folder, csv_file.strip())
        table_name = os.path.splitext(csv_file)[0].lower()  # Lowercase table names
        load_csv_to_postgresql(csv_file=csv_file_path, table_name=table_name, conn=connection, engine=engine)

if connection:
    connection.close()
    print("🔒 PostgreSQL connection closed.")
# Out:
# 📥 Creating table 'athletes'...
# 📊 Inserting data into 'athletes' (11085 rows)...
# ✅ Loaded ./data\Athletes.csv into table 'athletes'.
#
# 📥 Creating table 'coaches'...
# 📊 Inserting data into 'coaches' (394 rows)...
# ✅ Loaded ./data\Coaches.csv into table 'coaches'.
#
# 📥 Creating table 'entriesgender'...
# 📊 Inserting data into 'entriesgender' (46 rows)...
# ✅ Loaded ./data\EntriesGender.csv into table 'entriesgender'.
#
# 📥 Creating table 'medals'...
# 📊 Inserting data into 'medals' (93 rows)...
# ✅ Loaded ./data\Medals.csv into table 'medals'.
#
# 📥 Creating table 'teams'...
# 📊 Inserting data into 'teams' (743 rows)...
# ✅ Loaded ./data\Teams.csv into table 'teams'.
# 🔒 PostgreSQL connection closed.
